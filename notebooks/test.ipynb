# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# [03/24/23 00:52:40] INFO     Resolved project path as: /home/calychas/Projects/srai-kedro.          ]8;id=66147;file:///home/calychas/Projects/srai-kedro/venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=428394;file:///home/calychas/Projects/srai-kedro/venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/24/23 00:52:42] INFO     The 'tracking_uri' key in mlflow.yml is relative            ]8;id=278860;file:///home/calychas/Projects/srai-kedro/venv/lib/python3.10/site-packages/kedro_mlflow/config/kedro_mlflow_config.py\kedro_mlflow_config.py]8;;\:]8;id=572328;file:///home/calychas/Projects/srai-kedro/venv/lib/python3.10/site-packages/kedro_mlflow/config/kedro_mlflow_config.py#261\261]8;;\
#                              ('server.mlflow_(tracking|registry)_uri = mlruns'). It is
#                              converted to a valid uri:
# ...

# %%
df = catalog.load("embeddings")
df
# Out:
# [03/24/23 00:52:44] INFO     Loading data from 'embeddings' (PickleDataSet)...                  ]8;id=548457;file:///home/calychas/Projects/srai-kedro/venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=892005;file:///home/calychas/Projects/srai-kedro/venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                        0         1         2         3         4         5   \
# region_id
# 891e0590197ffff -0.262635 -0.193726  0.082927  0.148538  0.212324 -0.057117
# 891e05901b3ffff -0.240424 -0.199861  0.105286  0.062776  0.233326 -0.063041
# 891e05901b7ffff -0.240841 -0.235428  0.058686 -0.104218  0.191999 -0.125726
# 891e0590523ffff -0.240424 -0.199861  0.105286  0.062776  0.233326 -0.063041
# 891e0590527ffff -0.267078 -0.192498  0.078455  0.165690  0.208124 -0.055932
# ...                   ...       ...       ...       ...       ...       ...
# 891f725ae67ffff -0.815367 -0.224316 -0.221396  0.269753 -0.006938 -0.011979
# ...
